# %% [markdown]
# # Distribution

# %%
import pandas as pd

df = pd.read_csv("gs_entity.csv")

df['label'].value_counts()
# Out:
# label
# property_value_update    813
# refinement               357
# unrefinement             357
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("gs_text.csv")

df['label'].value_counts()
# Out:
# label
# property_value_update                       443
# textual_change                              433
# refinement                                  378
# unrefinement                                349
# refinement, unrefinement                     41
# textual_change, unrefinement                 29
# textual_change, refinement                   28
# unrefinement, textual_change                  2
# refinement, textual_change                    1
# textual_change, unrefinement, refinement      1
# Name: count, dtype: int64

# %%
import pandas as pd
from collections import Counter

df = pd.read_csv("gs_text.csv")

label_lists = df['label'].fillna('').str.split(',').apply(lambda x: [l.strip() for l in x if l.strip()])

class_counts = Counter(l for labels in label_lists for l in labels)

class_counts_series = pd.Series(class_counts).sort_values(ascending=False)
print(class_counts_series)
# Out:
# textual_change           494
# refinement               449
# property_value_update    443
# unrefinement             422
# dtype: int64
